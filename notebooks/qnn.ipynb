# %% [markdown]
# # Hybrid Quanttm - Classical Neural Networks
#
# Consist in :
#
# - Classical layers
# - Quantum layers
#
# ## Bolzmann Machine
# A Boltzmann Machine is a type of stochastic recurrent neural network that can learn complex probability distributions over its set of inputs. It consists of visible units (which represent the input data) and hidden units (which capture the underlying structure of the data). The connections between these units are undirected and can be weighted.
#
# ## Build a Hybrid Quantum-Classical AI Model
#
# 1. Generatte, preprocess and encode the data
# 2. Define a quantum circuit layer
# 3. Convert quantum circuit to to a PyTorch layer
# 4. Defina a Quantum-Classical Hybrid Neural Network
# 5. Train the Hybrid Model

# %%
import torch 
import torch.nn as nn
import torch.optim as optim 

from sklearn.datasets import make_moons 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from qiskit.primitives import StatevectorEstimator
from qiskit.circuit.library import real_amplitudes
from qiskit_machine_learning.neural_networks import EstimatorQNN 
from qiskit_machine_learning.connectors import TorchConnector

import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate data with Make Moons dataset from sklearn
# The Make Moons dataset is a synthetic dataset that consists of two interleaving half circles, often used for classification tasks. It is generated using the `make_moons` function from the `sklearn.datasets` module.

# %%
x,y = make_moons(n_samples=100, noise=0.1, random_state=42)
# can you help me import matplotlib.pyplot as plt to visualize the data? 

plt.scatter(x[:,0], x[:,1], c=y, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Make Moons Dataset')
plt.show()

# %% [markdown]
# ## Normalize and split the data into training and testing sets

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Convert quantum circuit to to a PyTorch tensors
# This hybrid model will use PyTorch for the classical part and Qiskit for the quantum part. We need to convert our data into PyTorch tensors to feed it into the model.

# %%
x_train_torch = torch.tensor(x_train, dtype=torch.float32)
x_test_torch  = torch.tensor(x_test, dtype=torch.float32)
y_train_torch = torch.tensor(y_train, dtype=torch.long)
y_test_torch  = torch.tensor(y_test, dtype=torch.long)

# %% [markdown]
# ## Define a quantum circuit layer (RealAmplitudes)
# The RealAmplitudes circuit is a parameterized quantum circuit that consists of layers of single-qubit rotation gates (RX, RY, RZ) followed by entangling gates (CNOT). It is commonly used in quantum machine learning applications as a variational ansatz for quantum neural networks.## Define a quantum circuit layer

# %%
num_qubits = 2
quantum_circuit = real_amplitudes(num_qubits, reps=1)
# Out:
# C:\Users\qimon\AppData\Local\Temp\ipykernel_35332\3892284786.py:2: DeprecationWarning: The class ``qiskit.circuit.library.n_local.real_amplitudes.RealAmplitudes`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.real_amplitudes instead.
#   quantum_circuit = RealAmplitudes(num_qubits, reps=1)
